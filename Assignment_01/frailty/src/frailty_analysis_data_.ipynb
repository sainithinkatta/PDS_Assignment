# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

from plotly.tools import FigureFactory as FF

# %%
# Load the cleaned frailty data from a CSV file into a Pandas DataFrame
frailty_data = pd.read_csv('/content/frailty/clean_data/frailty_clean_data.csv')

# %%
frailty_data
# Out:
#    Height (Inches)  Weight (Pounds)   Age  Grip strength  Frailty
# 0             65.8               112   30             30        1
# 1             71.5               136   19             31        1
# 2             69.4               153   45             29        1
# 3             68.2               142   22             28        0
# 4             67.8               144   29             24        0
# 5             68.7               123   50             26        1
# 6             69.8               141   51             22        0
# 7             70.1               136   23             20        0
# 8             67.9               112   17             19        1
# 9             66.8               120   39             31        1

# %%
# Conducting a two-sample t-test on the 'Weight (Pounds)' and 'Frailty' columns
weight = data['Weight (Pounds)']
frailty = data['Frailty']
t2_test = stats.ttest_ind(weight, frailty)

# Print the results of the t-test
print('Analysis:', t2_test)
# Out:
# Analysis: TtestResult(statistic=29.155389914737384, pvalue=1.3273210493059615e-16, df=18.0)

# %%
# Create a boxplot for the t-test results
sns.boxplot(data=t2_test)  # Use 'data' parameter for proper boxplot usage

# Save the boxplot as a PNG file
plt.savefig('/content/frailty/results/ttest_result.png')

# %%
# Create a box plot with 'Frailty' on the X-axis and 'Grip strength' on the Y-axis
sns.boxplot(x=data['Frailty'], y=data['Grip strength'])

# Save the box plot as a PNG file
plt.savefig('/content/frailty/results/result.png')

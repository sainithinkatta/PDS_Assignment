# %% [markdown]
# <a href="https://colab.research.google.com/github/sainithinkatta/PDS_Assignment/blob/main/Assignment_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/My Drive/train.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1           2                      Honda Jazz V     Chennai  2011
# 2           3                 Maruti Ertiga VDI     Chennai  2012
# 3           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4           6            Nissan Micra Diesel XV      Jaipur  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 1              46000    Petrol       Manual      First    13 km/kg  1199 CC
# 2              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 3              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
# 4              86999    Diesel       Manual      First  23.08 kmpl  1461 CC
#
#        Power  Seats  New_Price  Price
# 0  126.2 bhp    5.0        NaN  12.50
# ...

# %% [markdown]
# ## Missing Values (Mean, Median, Mode)

# %%
df['Mileage'].fillna(df['Mileage'].median(),inplace=True)
df['Engine'].fillna(df['Engine'].median(),inplace=True)
df['Power'].fillna(df['Power'].median(),inplace=True)

df['Seats'].fillna(df['Seats'].mode()[0],inplace=True)

df.drop('New_Price', axis=1, inplace=True)
# Out:
# <ipython-input-12-bf2f876a671e>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Mileage'].fillna(df['Mileage'].median(),inplace=True)
# <ipython-input-12-bf2f876a671e>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# dtype: int64

# %% [markdown]
# In the sections on power, engine, and mileage, we are substituting mean values for any missing numbers. This is because outliers have minimal impact on the mean, which compares the majority of the data. Since the mode indicates the number of seats that occur most frequently, we utilize it to fill in any blank values in the Seat column. To prevent erroneous data and analysis, the entire New Price column is being removed because more than half of its values are missing.

# %%
df.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1           2                      Honda Jazz V     Chennai  2011
# 2           3                 Maruti Ertiga VDI     Chennai  2012
# 3           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4           6            Nissan Micra Diesel XV      Jaipur  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 0              41000    Diesel       Manual      First    19.67  1582.0
# 1              46000    Petrol       Manual      First    13.00  1199.0
# 2              87000    Diesel       Manual      First    20.77  1248.0
# 3              40670    Diesel    Automatic     Second    15.20  1968.0
# 4              86999    Diesel       Manual      First    23.08  1461.0
#
#     Power  Seats  Price
# 0  126.20    5.0  12.50
# 1   88.70    5.0   4.50
# 2   88.76    7.0   6.00
# 3  140.80    5.0  17.74
# ...

# %% [markdown]
# ## Removing the Attributes

# %%
df['Mileage'] = df['Mileage'].astype(str).str.extract(r'(\d+\.?\d*)').astype(float)
df['Engine'] = df['Engine'].astype(str).str.extract(r'(\d+\.?\d*)').astype(float)
df['Power'] = df['Power'].astype(str).str.extract(r'(\d+\.?\d*)').astype(float)
df['New_Price'] = df['New_Price'].astype(str).str.extract(r'(\d+\.?\d*)').astype(float)

# %%
df.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1           2                      Honda Jazz V     Chennai  2011
# 2           3                 Maruti Ertiga VDI     Chennai  2012
# 3           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4           6            Nissan Micra Diesel XV      Jaipur  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 0              41000    Diesel       Manual      First    19.67  1582.0
# 1              46000    Petrol       Manual      First    13.00  1199.0
# 2              87000    Diesel       Manual      First    20.77  1248.0
# 3              40670    Diesel    Automatic     Second    15.20  1968.0
# 4              86999    Diesel       Manual      First    23.08  1461.0
#
#     Power  Seats  New_Price  Price
# 0  126.20    5.0        NaN  12.50
# 1   88.70    5.0       8.61   4.50
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  38
# New_Price            5032
# Price                   0
# dtype: int64

# %% [markdown]
# ## Hot Encoded Value

# %%
df['Fuel_Type'].replace({'Diesel': 0, 'Petrol': 1, 'Electric': 2}, inplace=True)
df['Transmission'].replace({'Manual': 0, 'Automatic': 1}, inplace=True)
# Out:
# <ipython-input-15-caee3d638869>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Fuel_Type'].replace({'Diesel': 0, 'Petrol': 1, 'Electric': 2}, inplace=True)
# <ipython-input-15-caee3d638869>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1           2                      Honda Jazz V     Chennai  2011
# 2           3                 Maruti Ertiga VDI     Chennai  2012
# 3           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4           6            Nissan Micra Diesel XV      Jaipur  2013
#
#    Kilometers_Driven  Fuel_Type  Transmission Owner_Type  Mileage  Engine  \
# 0              41000          0             0      First    19.67  1582.0
# 1              46000          1             0      First    13.00  1199.0
# 2              87000          0             0      First    20.77  1248.0
# 3              40670          0             1     Second    15.20  1968.0
# 4              86999          0             0      First    23.08  1461.0
#
#     Power  Seats  Price
# 0  126.20    5.0  12.50
# 1   88.70    5.0   4.50
# 2   88.76    7.0   6.00
# ...

# %% [markdown]
# ## Creating one more feature

# %%
from datetime import datetime

# %%
now = datetime.now().year

df['Car_Age'] = now - df['Year']

# %%
df.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1           2                      Honda Jazz V     Chennai  2011
# 2           3                 Maruti Ertiga VDI     Chennai  2012
# 3           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4           6            Nissan Micra Diesel XV      Jaipur  2013
#
#    Kilometers_Driven  Fuel_Type  Transmission Owner_Type  Mileage  Engine  \
# 0              41000          0             0      First    19.67  1582.0
# 1              46000          1             0      First    13.00  1199.0
# 2              87000          0             0      First    20.77  1248.0
# 3              40670          0             1     Second    15.20  1968.0
# 4              86999          0             0      First    23.08  1461.0
#
#     Power  Seats  Price  Car_Age
# 0  126.20    5.0  12.50        9
# 1   88.70    5.0   4.50       13
# ...

# %% [markdown]
# ## Operations

# %%
selected_columns = df[['Mileage', 'Engine']]

# %%
selected_columns.head()
# Out:
#    Mileage  Engine
# 0    19.67  1582.0
# 1    13.00  1199.0
# 2    20.77  1248.0
# 3    15.20  1968.0
# 4    23.08  1461.0

# %%
filter_data = df[df['Year'] > 2013]

# %%
filter_data.head()
# Out:
#     Unnamed: 0                               Name Location  Year  \
# 0            1   Hyundai Creta 1.6 CRDi SX Option     Pune  2015
# 5            7  Toyota Innova Crysta 2.8 GX AT 8S   Mumbai  2016
# 8           10                   Maruti Ciaz Zeta    Kochi  2018
# 10          12              Maruti Swift VDI BSIV   Jaipur  2015
# 11          13   Land Rover Range Rover 2.2L Pure    Delhi  2014
#
#     Kilometers_Driven  Fuel_Type  Transmission Owner_Type  Mileage  Engine  \
# 0               41000          0             0      First    19.67  1582.0
# 5               36000          0             1      First    11.36  2755.0
# 8               25692          1             0      First    21.56  1462.0
# 10              64424          0             0      First    25.20  1248.0
# 11              72000          0             1      First    12.70  2179.0
#
#      Power  Seats  Price  Car_Age
# 0   126.20    5.0  12.50        9
# 5   171.50    8.0  17.50        8
# ...

# %%
df.rename(columns={'Location': 'Place_Manufactured', 'Power': 'Horsepower'}, inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0                              Name Place_Manufactured  Year  \
# 0           1  Hyundai Creta 1.6 CRDi SX Option               Pune  2015
# 1           2                      Honda Jazz V            Chennai  2011
# 2           3                 Maruti Ertiga VDI            Chennai  2012
# 3           4   Audi A4 New 2.0 TDI Multitronic         Coimbatore  2013
# 4           6            Nissan Micra Diesel XV             Jaipur  2013
#
#    Kilometers_Driven  Fuel_Type  Transmission Owner_Type  Mileage  Engine  \
# 0              41000          0             0      First    19.67  1582.0
# 1              46000          1             0      First    13.00  1199.0
# 2              87000          0             0      First    20.77  1248.0
# 3              40670          0             1     Second    15.20  1968.0
# 4              86999          0             0      First    23.08  1461.0
#
#    Horsepower  Seats  Price  Car_Age
# 0      126.20    5.0  12.50        9
# ...

# %%
arranged_data = df.sort_values(by='Price')

# %%
arranged_data.head()
# Out:
#       Unnamed: 0                  Name Place_Manufactured  Year  \
# 1660        1713          Tata Nano Lx               Pune  2011
# 2758        2847      Hyundai Getz GLS               Pune  2005
# 1577        1628  Maruti 800 Std BSIII             Jaipur  2004
# 3039        3138        Maruti Zen LXI             Jaipur  1998
# 3127        3228        Maruti 800 Std               Pune  2003
#
#       Kilometers_Driven  Fuel_Type  Transmission Owner_Type  Mileage  Engine  \
# 1660              65000          1             0     Second     26.0   624.0
# 2758              86000          1             0     Second     15.3  1341.0
# 1577              12000          1             0     Second     16.1   796.0
# 3039              95150          1             0      Third     17.3   993.0
# 3127              52000          1             0      First     16.1   796.0
#
#       Horsepower  Seats  Price  Car_Age
# 1660        35.0    4.0   0.44       13
# ...

# %%
summary = df.groupby('Fuel_Type')['Horsepower'].mean().reset_index()

# %%
summary.head()
# Out:
#    Fuel_Type  Horsepower
# 0          0  127.828966
# 1          1   97.123066
# 2          2   57.000000

# %%
df['Mileage_per_CC'] = df['Mileage'] / df['Engine']

# %%
df.head()
# Out:
#    Unnamed: 0                              Name Place_Manufactured  Year  \
# 0           1  Hyundai Creta 1.6 CRDi SX Option               Pune  2015
# 1           2                      Honda Jazz V            Chennai  2011
# 2           3                 Maruti Ertiga VDI            Chennai  2012
# 3           4   Audi A4 New 2.0 TDI Multitronic         Coimbatore  2013
# 4           6            Nissan Micra Diesel XV             Jaipur  2013
#
#    Kilometers_Driven  Fuel_Type  Transmission Owner_Type  Mileage  Engine  \
# 0              41000          0             0      First    19.67  1582.0
# 1              46000          1             0      First    13.00  1199.0
# 2              87000          0             0      First    20.77  1248.0
# 3              40670          0             1     Second    15.20  1968.0
# 4              86999          0             0      First    23.08  1461.0
#
#    Horsepower  Seats  Price  Car_Age  Mileage_per_CC
# ...
